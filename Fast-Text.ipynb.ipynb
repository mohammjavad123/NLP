# %%
# !pip install fasttext
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 3.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from fasttext) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fasttext) (2.0.2)
# Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp311-cp311-linux_x86_64.whl size=4313502 sha256=d7073abec59ca5a4fba66fc52ea0f29388d674ff28e32228147db49f4bd57080
#   Stored in directory: /root/.cache/pip/wheels/65/4f/35/5057db0249224e9ab55a513fa6b79451473ceb7713017823c3
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-2.13.6

# %%
# !pip install numpy==1.26.4
import os
os.kill(os.getpid(), 9)  # Restart the runtime (needed in Colab)
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 44.5 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed numpy-1.26.4

# %%
# !wget 'https://www.dropbox.com/scl/fi/eyrwvty94p331ew77p6u9/semantic_tech_real70.csv?rlkey=7qpqq9ut48tln36l1av6qc6ww&st=t0vny14l&dl=1'
# Out:
# --2025-04-03 22:09:47--  https://www.dropbox.com/scl/fi/eyrwvty94p331ew77p6u9/semantic_tech_real70.csv?rlkey=7qpqq9ut48tln36l1av6qc6ww&st=t0vny14l&dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0ba9f6bcbf86c0ecddff38ecaf.dl.dropboxusercontent.com/cd/0/inline/CnInuGbDrWuDmODV0CrYPivd7ZDOYXstSYqZLeqOwgFK8dLLhvxyFziGWsMOqrsorlt_-LCjg9nHcVwf8CHkgmyCpzFpqzWjWUkcR0UYzVh7knr8HtLntggxMM_QQWTjNJ24q2DKPkWYIHPBaS7RfSif/file?dl=1# [following]
# --2025-04-03 22:09:47--  https://uc0ba9f6bcbf86c0ecddff38ecaf.dl.dropboxusercontent.com/cd/0/inline/CnInuGbDrWuDmODV0CrYPivd7ZDOYXstSYqZLeqOwgFK8dLLhvxyFziGWsMOqrsorlt_-LCjg9nHcVwf8CHkgmyCpzFpqzWjWUkcR0UYzVh7knr8HtLntggxMM_QQWTjNJ24q2DKPkWYIHPBaS7RfSif/file?dl=1
# Resolving uc0ba9f6bcbf86c0ecddff38ecaf.dl.dropboxusercontent.com (uc0ba9f6bcbf86c0ecddff38ecaf.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc0ba9f6bcbf86c0ecddff38ecaf.dl.dropboxusercontent.com (uc0ba9f6bcbf86c0ecddff38ecaf.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63056349 (60M) [application/binary]
# Saving to: ‘semantic_tech_real70.csv?rlkey=7qpqq9ut48tln36l1av6qc6ww&st=t0vny14l&dl=1’
#
# semantic_tech_real7 100%[===================>]  60.13M  31.0MB/s    in 1.9s
#
# 2025-04-03 22:09:50 (31.0 MB/s) - ‘semantic_tech_real70.csv?rlkey=7qpqq9ut48tln36l1av6qc6ww&st=t0vny14l&dl=1’ saved [63056349/63056349]

# %% [markdown]
# better results

# %% [markdown]
# fresh start

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load dataset
df = pd.read_csv('/content/semantic_tech_real70.csv')

# Map to FastText-friendly labels
label_map = {-1: 'NEG', 0: 'NEU', 1: 'POS'}
df['sentiment_label'] = df['sentiment'].map(label_map)

# Build FastText training format
df['fasttext_format'] = '__label__' + df['sentiment_label'] + ' ' + df['review_text'].astype(str)

# Train-test split
train_df, test_df = train_test_split(df['fasttext_format'], test_size=0.2, stratify=df['sentiment_label'], random_state=42)

# Save to .txt
train_df.to_csv('fasttext_train.txt', index=False, header=False)
test_df.to_csv('fasttext_test.txt', index=False, header=False)

# Show a few samples to verify
print("Sample from training file:")
print(train_df.sample(5).values)

print("\nSample from test file:")
print(test_df.sample(5).values)
# Out:
# Sample from training file:
# ["__label__NEU I like that the case protects the machine from scratches. It fits on the A1181 just right except that the circle does not go exactly around the apple. It is off quite a bit. But I'd rather it protects the machine so I don't care that much and for $13 I can't really complain. Also ordered the matching keyboard/palmrest cover. I like that but it collects so much dust underneath it drives me crazy! It does fit right but the &#34;F&#34; key markings are incorrect, luckily I already know what they do and don't require the cover to tell me."
#  "__label__POS It's cheap and it works perfectly.  Not much you can ask from it.  Using in a 2012 Macbook Pro.  ."
#  '__label__NEU For the price you really cant complain. It does its job, its a tad dificult to get on the ipad.  The holes dont line up perfectly.  It does keep the ipad safer than uncovered.'
#  "__label__NEG I own an iPad4,samsung galaxy 7 tab 2 and very satisfied  and  i also tried acer model with win7 before ,for this  built is ok but its too big to hold in hand as an tablet ,front camera seems terrible with regular window 8 program calling some problem to work every time you select it then its gone ,so didn't worked at all ,for  Netflix it run  grainy and blurry exploded pixel so app are not written for high resolution . If you are looking for fluidity like iPad 4 just forget about it. Window will never work on tablet version , i also sold my viliv s5 because it lack physical keyboard and front camera  ( so problem with window 8 again ) .its never for tablet version . Mine is going back again and i have to stick with desktop PC and iPad 4 and android and iPhone  , window is only for laptops . Samsung need to make a smaller version with 5-6 inch screen ( capacitive touch ) with 1080p resolution screen and a physical slider keyboard ( because its just window requirement ) .other wise tablet dream of window seems an dead end ."
#  "__label__NEG These clips are flimsy. It's a great theory, but I have six of them that can't hold anything. They are nothing but JUNK! Maybe if they were created with a harder plastic, they might work. It's a shame because I really needed something sturdy that could hold all my Apple cords. Oh well, live and learn."]
#
# Sample from test file:
# ['__label__NEG I ordered one of these for my 2011 i5 iMac because of its overwhelming positive reviews thinking it would improve the sound going to my AudioEngine A5s.Unfortunately, it\'s a big fat "NO."  If anything, it made the sound significantly worse; it changed the sound dynamics altogether: soundstage became different and took away some of the bass.  Yes, I did follow the 48-hour break-in period but it still sounded the same.And the "headphone amp?"  What can I say?  Even worse.  I suppose I don\'t need to expect much since it has no power on its own (depends fully on the powered USB port of the computer it\'s attached to) but it can barely drive a relatively low-impedance Grado headphones.  Again, soundstage different (worse to me, YMMV), bass is almost gone...and static on high frequencies.  My CMOY amp housed in an Altoids tin can sounded much better.I gotta give it to NuForce for the lovely design of the case.  Unfortunately, nobody cares about the design of the case if the sound is not good.The positive thing I can say is that you will realize how good the headphone/line out the iMac already is.Majority can\'t be wrong, right?  In this case, it can.  Also, I know the owner lurks on reviews and monitors the bad reviews and tries to convince the reviewer otherwise.  I stand by my review and I have no other reason to provide a bad review except for the fact that this is not a good product.  Especially when there is one exhaustive review out there about this DAC that validates my experience (google it).'
#  '__label__NEG Despite the title and other reviews saying this would work, I could not get it to pair with my retina macbook pro. I took it to the genius bar and they could not get it to pair either.'
#  '__label__POS I have baseline knowledge of computers and home networks, which is unfortunate, since I have iPhones, iPods, iPads, netbooks, Sony tablets, Wii, PS3, Xbox360, and laptops in my home.I was absolutely distraught to realize my used-a lot Netgear router was dying. To set up my home network again just gave me nightmares.  But...This router is amazing! I shut off all my computers, turned wifi off on all my devices, and plugged in the new router. Upon reactivating my devices wifi and turning my computers back on, all network settings were a snap and I had 2.4 Ghz and 5 Ghz speeds to all devices and home networking set up within 15 minutes, including my printer that is attached to one of my home computers, this router found it and asked if I wanted it shared with all devices!!  I absolutely enjoyed setting up this new router and it has amazing speed and connectivity.'
#  "__label__POS I bought this laptop for a friend who needs travel every day. It is the first Lenovo that i recommended. It has a hard plastic case which is very convenient for this purpose. The keyboard and touchpad have been working normally. There aren't HDD or caps lock leds, but i think it is only a minor caveat. It comes with windows 7! My friend thinks this makes it all the more important"
#  "__label__NEU Very nice color, excellent skin tones, the blacks are not very good though. The main problem is motion blur, when watching sports, a lot of the action is blurred and pixelated. Definitly not a 120 hz tv, as I have a couple Samsungs with 120hz and there is no motion blur. I noticed consumer reports complained about the same thing. This doesn't happen on all programming, on some things it wasn't noticeable, so it may or may not bother you. I ended up with the Samsung 6300 and couldn't be happier."]

# %% [markdown]
# new hyperparameter

# %%
text = "This laptop is amazing. Super fast and great battery life!"
labels, probabilities = model.predict(text, k=1)
print(labels, probabilities)
# Out:
# ('__label__POS',) [1.00001001]

# %%
text = "This laptop is bad.  slow and weak battery life!I don't want it "
labels, probabilities = model.predict(text, k=1)
print(labels, probabilities)
# Out:
# ('__label__NEG',) [1.00000906]

# %%
text = "I LIke the design but medium performance"
labels, probabilities = model.predict(text, k=1)
print(labels, probabilities)
# Out:
# ('__label__NEU',) [1.00001001]

# %%
import pandas as pd

# Reload original dataset to get true labels
df = pd.read_csv('/content/semantic_tech_real70.csv')

# Map labels
label_map = {-1: 'NEG', 0: 'NEU', 1: 'POS'}
df['sentiment_label'] = df['sentiment'].map(label_map)

# Stratified split (same as training)
from sklearn.model_selection import train_test_split
_, test_df = train_test_split(df, test_size=0.2, stratify=df['sentiment_label'], random_state=42)

# %%
# Load the trained model
import fasttext
model = fasttext.load_model("sentiment_fasttext.bin")

# Predict all samples
y_true = test_df['sentiment_label'].tolist()
y_pred = []
probs = []

for text in test_df['review_text'].astype(str):
    label, prob = model.predict(text, k=1)
    y_pred.append(label[0].replace('__label__', ''))
    probs.append(prob[0])

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Report
print(classification_report(y_true, y_pred, digits=4))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred, labels=["NEG", "NEU", "POS"])

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=["NEG", "NEU", "POS"],
            yticklabels=["NEG", "NEU", "POS"])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          NEG     0.6750    0.5807    0.6243      3802
#          NEU     0.4803    0.4699    0.4751      3407
#          POS     0.7444    0.8177    0.7794      6145
#
#     accuracy                         0.6615     13354
#    macro avg     0.6333    0.6228    0.6263     13354
# weighted avg     0.6573    0.6615    0.6576     13354

# %%
import numpy as np

plt.hist(probs, bins=20, edgecolor='k')
plt.title("FastText Prediction Confidence (Top-1)")
plt.xlabel("Confidence")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import pandas as pd

df = pd.read_csv('/content/semantic_tech_real50.csv')
df['sentiment'].value_counts(normalize=True)
# Out:
# sentiment
#  1    0.447565
# -1    0.295678
#  0    0.256756
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

label_map = {-1: 'NEG', 0: 'NEU', 1: 'POS'}
df['label'] = df['sentiment'].map(label_map)

sns.countplot(x='label', data=df, order=['NEG', 'NEU', 'POS'])
plt.title("Sentiment Class Distribution")
plt.ylabel("Number of Reviews")
plt.xlabel("Sentiment")
plt.show()

# %%
df['text_length'] = df['review_text'].astype(str).apply(lambda x: len(x.split()))

plt.figure(figsize=(8,5))
sns.histplot(data=df, x='text_length', hue='label', bins=30, kde=True, element="step")
plt.title("Distribution of Review Lengths by Sentiment")
plt.xlabel("Number of Words")
plt.ylabel("Frequency")
plt.show()

# %%
from wordcloud import WordCloud

for sentiment in ['NEG', 'NEU', 'POS']:
    text = " ".join(df[df['label'] == sentiment]['review_text'].dropna().astype(str))
    wc = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"Word Cloud - {sentiment}")
    plt.show()

# %%
print(df[['review_text', 'label']].sample(3))
# Out:
#                                              review_text label
# 25527  Really does increase volume!  Never understood...   POS
# 5053   Bought this unit before any reviews were poste...   NEG
# 9004   I've bought this charger after reading much hy...   NEG

# %%
import os

size_bytes = os.path.getsize("sentiment_fasttext.bin")
size_mb = size_bytes / (1024 * 1024)
print(f"Model size: {size_mb:.2f} MB")
# Out:
# Model size: 894.68 MB

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_true, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#          NEG     0.6750    0.5807    0.6243      3802
#          NEU     0.4803    0.4699    0.4751      3407
#          POS     0.7444    0.8177    0.7794      6145
#
#     accuracy                         0.6615     13354
#    macro avg     0.6333    0.6228    0.6263     13354
# weighted avg     0.6573    0.6615    0.6576     13354

# %%
cm = confusion_matrix(y_true, y_pred, labels=["NEG", "NEU", "POS"])
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=["NEG", "NEU", "POS"],
            yticklabels=["NEG", "NEU", "POS"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
